# %%
import pandas as pd

# %%
# prompt: from google.colab impot files
from google.colab import files

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-7aedbcc8-5de6-4817-b28c-858b4db9194c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7aedbcc8-5de6-4817-b28c-858b4db9194c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io

# %%
df=pd.read_csv(io.BytesIO(uploaded ['StudentPerformanceFactors.csv']))

# %%
#PRINTING 5 RECORDS FOR CSV FILE.
print(df.head(5))
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
#SUM OF MISSING COLUMN ENTRIES.
df.isna().sum()

df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
print({df.size})
# Out:
# {132140}

# %%
#SUM OF NUMERICAL ENTRIES
print(df.select_dtypes(include='number').sum())
# Out:
# Hours_Studied        131977
# Attendance           528411
# Sleep_Hours           46441
# Previous_Scores      495991
# Tutoring_Sessions      9869
# Physical_Activity     19607
# Exam_Score           444226
# dtype: int64

# %%
#AVERAGE OF NUMERICAL ENTRIES
print(df.select_dtypes(include='number').mean())
# Out:
# Hours_Studied        19.975329
# Attendance           79.977448
# Sleep_Hours           7.029060
# Previous_Scores      75.070531
# Tutoring_Sessions     1.493719
# Physical_Activity     2.967610
# Exam_Score           67.235659
# dtype: float64

# %%
#MINIMUM OF NUMERICAL ENTRIES
print(df.select_dtypes(include='number').min())
# Out:
# Hours_Studied         1
# Attendance           60
# Sleep_Hours           4
# Previous_Scores      50
# Tutoring_Sessions     0
# Physical_Activity     0
# Exam_Score           55
# dtype: int64

# %%
#MAX OF NUMERICAL ENTRIES
print(df.select_dtypes(include='number').max())
# Out:
# Hours_Studied         44
# Attendance           100
# Sleep_Hours           10
# Previous_Scores      100
# Tutoring_Sessions      8
# Physical_Activity      6
# Exam_Score           101
# dtype: int64
